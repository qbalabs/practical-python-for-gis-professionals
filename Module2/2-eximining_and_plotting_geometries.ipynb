# %%
# %matplotlib inline

import geopandas as gp

pp=gp.GeoDataFrame.from_file('zip:///home/jovyan/ne_c.zip')

# %%
pp
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 1            1  Admin-0 country        3.0                       Angola
# 2            1  Admin-0 country        6.0                      Albania
# 3            1  Admin-0 country        4.0         United Arab Emirates
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 6            1  Admin-0 country        4.0                   Antarctica
# 7            3  Admin-0 country        6.0                       France
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 11           1  Admin-0 country        6.0                      Burundi
# ...

# %%
print(pp.geometry)
# Out:
# 0      POLYGON ((61.21081709172574 35.65007233330923,...
# 1      (POLYGON ((23.90415368011818 -11.7222815894063...
# 2      POLYGON ((21.0200403174764 40.84272695572588, ...
# 3      POLYGON ((51.57951867046327 24.24549713795111,...
# 4      (POLYGON ((-66.95992000000001 -54.896810000000...
# 5      POLYGON ((43.58274580259273 41.09214325618257,...
# 6      (POLYGON ((-59.57209469261159 -80.040178725096...
# 7      POLYGON ((68.935 -48.62500000000001, 69.58 -48...
# 8      (POLYGON ((145.3979781434949 -40.7925485166059...
# 9      POLYGON ((16.97966678230404 48.12349701597631,...
# 10     (POLYGON ((46.50571984231797 38.77060537368629...
# 11     POLYGON ((29.33999759290035 -4.499983412294092...
# 12     POLYGON ((4.047071160507528 51.26725861266857,...
# 13     POLYGON ((2.691701694356254 6.258817246928629,...
# 14     POLYGON ((2.154473504249921 11.94015005131334,...
# 15     POLYGON ((92.67272098182556 22.04123891854125,...
# ...

# %%
pp.geometry.name
# Out:
# 'geometry'

# %%
pp.geom_type
# Out:
# 0           Polygon
# 1      MultiPolygon
# 2           Polygon
# 3           Polygon
# 4      MultiPolygon
# 5           Polygon
# 6      MultiPolygon
# 7           Polygon
# 8      MultiPolygon
# 9           Polygon
# 10     MultiPolygon
# 11          Polygon
# 12          Polygon
# 13          Polygon
# 14          Polygon
# 15          Polygon
# 16          Polygon
# 17     MultiPolygon
# 18          Polygon
# 19          Polygon
# 20          Polygon
# 21          Polygon
# 22          Polygon
# 23          Polygon
# 24          Polygon
# 25          Polygon
# 26          Polygon
# 27     MultiPolygon
# 28          Polygon
# 29     MultiPolygon
#            ...
# 147         Polygon
# 148         Polygon
# 149         Polygon
# 150         Polygon
# 151         Polygon
# 152         Polygon
# 153         Polygon
# 154         Polygon
# 155         Polygon
# 156         Polygon
# 157         Polygon
# 158         Polygon
# 159         Polygon
# 160         Polygon
# ...

# %%
pp[pp['ADMIN'] == 'France']
# Out:
#     scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 55          1  Admin-0 country        2.0     France    FR1       1.0    2.0
#
#        TYPE   ADMIN ADM0_A3  \
# 55  Country  France     FRA
#
#                           ...                                      REGION_WB  \
# 55                        ...                          Europe & Central Asia
#
#    NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 55      6.0      6.0         3.0 -99.0      1.0       0.0       1.7       6.7
#
#                                              geometry
# 55  (POLYGON ((2.513573032246114 51.14850617126189...
#
# [1 rows x 72 columns]

# %%
pp[pp['ADMIN'] == 'France'].crs
# Out:
# {'init': 'epsg:4326'}

# %%
pp[pp['ADMIN'] == 'France'].plot()

# %%
pp.plot()

# %%
pp[pp['ADMIN'] == 'France'].area
# Out:
# 55    72.621189
# dtype: float64

# %%
pp[pp['ADMIN'] == 'France'].bounds
# Out:
#          minx      miny      maxx       maxy
# 55 -54.524754  2.053389  9.560016  51.148506

# %%
pp[pp['ADMIN'] == 'France'].is_valid
# Out:
# 55    True
# dtype: bool

# %%
pp[pp['ADMIN'] == 'France'].centroid
# Out:
# 55    POINT (-2.880599191404037 42.45771810478762)
# dtype: object

# %%
pp[pp['ADMIN'] == 'France'].centroid.plot()
