# %%
import geopandas as gp

pp=gp.GeoDataFrame.from_file('zip:///home/jovyan/ne_c.zip')

# %% [markdown]
# ** Getting an overview of data **

# %%
pp
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 1            1  Admin-0 country        3.0                       Angola
# 2            1  Admin-0 country        6.0                      Albania
# 3            1  Admin-0 country        4.0         United Arab Emirates
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 6            1  Admin-0 country        4.0                   Antarctica
# 7            3  Admin-0 country        6.0                       France
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 11           1  Admin-0 country        6.0                      Burundi
# ...

# %%
print(pp)
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 1            1  Admin-0 country        3.0                       Angola
# 2            1  Admin-0 country        6.0                      Albania
# 3            1  Admin-0 country        4.0         United Arab Emirates
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 6            1  Admin-0 country        4.0                   Antarctica
# 7            3  Admin-0 country        6.0                       France
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 11           1  Admin-0 country        6.0                      Burundi
# ...

# %%
pp.head()
# Out:
#    scalerank       featurecla  LABELRANK            SOVEREIGNT SOV_A3  \
# 0          1  Admin-0 country        3.0           Afghanistan    AFG
# 1          1  Admin-0 country        3.0                Angola    AGO
# 2          1  Admin-0 country        6.0               Albania    ALB
# 3          1  Admin-0 country        4.0  United Arab Emirates    ARE
# 4          1  Admin-0 country        2.0             Argentina    ARG
#
#    ADM0_DIF  LEVEL               TYPE                 ADMIN ADM0_A3  \
# 0       0.0    2.0  Sovereign country           Afghanistan     AFG
# 1       0.0    2.0  Sovereign country                Angola     AGO
# 2       0.0    2.0  Sovereign country               Albania     ALB
# 3       0.0    2.0  Sovereign country  United Arab Emirates     ARE
# 4       0.0    2.0  Sovereign country             Argentina     ARG
#
#                          ...                          \
# 0                        ...
# 1                        ...
# ...

# %%
pp.sample()
# Out:
#     scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 13          1  Admin-0 country        5.0      Benin    BEN       0.0    2.0
#
#                  TYPE  ADMIN ADM0_A3  \
# 13  Sovereign country  Benin     BEN
#
#                           ...                                   REGION_WB  \
# 13                        ...                          Sub-Saharan Africa
#
#    NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 13      5.0      5.0         5.0 -99.0      1.0       0.0       4.0       9.0
#
#                                              geometry
# 13  POLYGON ((2.691701694356254 6.258817246928629,...
#
# [1 rows x 72 columns]

# %%
pp.sample(5)
# Out:
#     scalerank       featurecla  LABELRANK  SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 90          1  Admin-0 country        4.0        Laos    LAO       0.0    2.0
# 95          1  Admin-0 country        6.0     Lesotho    LSO       0.0    2.0
# 58          1  Admin-0 country        5.0     Georgia    GEO       0.0    2.0
# 72          1  Admin-0 country        2.0   Indonesia    IDN       0.0    2.0
# 83          1  Admin-0 country        3.0  Kazakhstan    KAZ       0.0    2.0
#
#                  TYPE       ADMIN ADM0_A3  \
# 90  Sovereign country        Laos     LAO
# 95  Sovereign country     Lesotho     LSO
# 58  Sovereign country     Georgia     GEO
# 72  Sovereign country   Indonesia     IDN
# 83  Sovereign country  Kazakhstan     KAZ
#
#                           ...                                      REGION_WB  \
# 90                        ...                            East Asia & Pacific
# 95                        ...                             Sub-Saharan Africa
# ...

# %%
pp.columns
# Out:
# Index(['scalerank', 'featurecla', 'LABELRANK', 'SOVEREIGNT', 'SOV_A3',
#        'ADM0_DIF', 'LEVEL', 'TYPE', 'ADMIN', 'ADM0_A3', 'GEOU_DIF', 'GEOUNIT',
#        'GU_A3', 'SU_DIF', 'SUBUNIT', 'SU_A3', 'BRK_DIFF', 'NAME', 'NAME_LONG',
#        'BRK_A3', 'BRK_NAME', 'BRK_GROUP', 'ABBREV', 'POSTAL', 'FORMAL_EN',
#        'FORMAL_FR', 'NAME_CIAWF', 'NOTE_ADM0', 'NOTE_BRK', 'NAME_SORT',
#        'NAME_ALT', 'MAPCOLOR7', 'MAPCOLOR8', 'MAPCOLOR9', 'MAPCOLOR13',
#        'POP_EST', 'POP_RANK', 'GDP_MD_EST', 'POP_YEAR', 'LASTCENSUS',
#        'GDP_YEAR', 'ECONOMY', 'INCOME_GRP', 'WIKIPEDIA', 'FIPS_10_', 'ISO_A2',
#        'ISO_A3', 'ISO_A3_EH', 'ISO_N3', 'UN_A3', 'WB_A2', 'WB_A3', 'WOE_ID',
#        'WOE_ID_EH', 'WOE_NOTE', 'ADM0_A3_IS', 'ADM0_A3_US', 'ADM0_A3_UN',
#        'ADM0_A3_WB', 'CONTINENT', 'REGION_UN', 'SUBREGION', 'REGION_WB',
#        'NAME_LEN', 'LONG_LEN', 'ABBREV_LEN', 'TINY', 'HOMEPART', 'MIN_ZOOM',
#        'MIN_LABEL', 'MAX_LABEL', 'geometry'],
#       dtype='object')

# %%
list(pp.columns)
# Out:
# ['scalerank',
#  'featurecla',
#  'LABELRANK',
#  'SOVEREIGNT',
#  'SOV_A3',
#  'ADM0_DIF',
#  'LEVEL',
#  'TYPE',
#  'ADMIN',
#  'ADM0_A3',
#  'GEOU_DIF',
#  'GEOUNIT',
#  'GU_A3',
#  'SU_DIF',
#  'SUBUNIT',
#  'SU_A3',
#  'BRK_DIFF',
#  'NAME',
#  'NAME_LONG',
#  'BRK_A3',
#  'BRK_NAME',
#  'BRK_GROUP',
#  'ABBREV',
#  'POSTAL',
#  'FORMAL_EN',
#  'FORMAL_FR',
#  'NAME_CIAWF',
#  'NOTE_ADM0',
#  'NOTE_BRK',
#  'NAME_SORT',
#  'NAME_ALT',
#  'MAPCOLOR7',
#  'MAPCOLOR8',
#  'MAPCOLOR9',
#  'MAPCOLOR13',
#  'POP_EST',
#  'POP_RANK',
#  'GDP_MD_EST',
#  'POP_YEAR',
#  'LASTCENSUS',
#  'GDP_YEAR',
#  'ECONOMY',
#  'INCOME_GRP',
#  'WIKIPEDIA',
#  'FIPS_10_',
#  'ISO_A2',
#  'ISO_A3',
#  'ISO_A3_EH',
#  'ISO_N3',
#  'UN_A3',
#  'WB_A2',
#  'WB_A3',
#  'WOE_ID',
#  'WOE_ID_EH',
#  'WOE_NOTE',
#  'ADM0_A3_IS',
#  'ADM0_A3_US',
#  'ADM0_A3_UN',
#  'ADM0_A3_WB',
#  'CONTINENT',
#  'REGION_UN',
#  'SUBREGION',
#  'REGION_WB',
#  'NAME_LEN',
#  'LONG_LEN',
#  'ABBREV_LEN',
#  'TINY',
# ...

# %% [markdown]
# ** Selecting specific columns **

# %%
pp['NAME']
# Out:
# 0                   Afghanistan
# 1                        Angola
# 2                       Albania
# 3          United Arab Emirates
# 4                     Argentina
# 5                       Armenia
# 6                    Antarctica
# 7        Fr. S. Antarctic Lands
# 8                     Australia
# 9                       Austria
# 10                   Azerbaijan
# 11                      Burundi
# 12                      Belgium
# 13                        Benin
# 14                 Burkina Faso
# 15                   Bangladesh
# 16                     Bulgaria
# 17                      Bahamas
# 18             Bosnia and Herz.
# 19                      Belarus
# 20                       Belize
# 21                      Bolivia
# 22                       Brazil
# 23                       Brunei
# 24                       Bhutan
# 25                     Botswana
# 26         Central African Rep.
# 27                       Canada
# 28                  Switzerland
# ...

# %%
pp[['NAME','REGION_WB']]
# Out:
#                          NAME                   REGION_WB
# 0                 Afghanistan                  South Asia
# 1                      Angola          Sub-Saharan Africa
# 2                     Albania       Europe & Central Asia
# 3        United Arab Emirates  Middle East & North Africa
# 4                   Argentina   Latin America & Caribbean
# 5                     Armenia       Europe & Central Asia
# 6                  Antarctica                  Antarctica
# 7      Fr. S. Antarctic Lands          Sub-Saharan Africa
# 8                   Australia         East Asia & Pacific
# 9                     Austria       Europe & Central Asia
# 10                 Azerbaijan       Europe & Central Asia
# 11                    Burundi          Sub-Saharan Africa
# 12                    Belgium       Europe & Central Asia
# 13                      Benin          Sub-Saharan Africa
# 14               Burkina Faso          Sub-Saharan Africa
# ...

# %% [markdown]
# *** Selecting rows ***

# %%
pp.iloc[[0]]
# Out:
#    scalerank       featurecla  LABELRANK   SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 0          1  Admin-0 country        3.0  Afghanistan    AFG       0.0    2.0
#
#                 TYPE        ADMIN ADM0_A3  \
# 0  Sovereign country  Afghanistan     AFG
#
#                          ...                           REGION_WB NAME_LEN  \
# 0                        ...                          South Asia     11.0
#
#   LONG_LEN  ABBREV_LEN  TINY HOMEPART  MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 0     11.0         4.0 -99.0      1.0       0.0       3.0       7.0
#
#                                             geometry
# 0  POLYGON ((61.21081709172574 35.65007233330923,...
#
# [1 rows x 72 columns]

# %%
pp.iloc[[4,8]]
# Out:
#    scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 4          1  Admin-0 country        2.0  Argentina    ARG       0.0    2.0
# 8          1  Admin-0 country        2.0  Australia    AU1       1.0    2.0
#
#                 TYPE      ADMIN ADM0_A3  \
# 4  Sovereign country  Argentina     ARG
# 8            Country  Australia     AUS
#
#                          ...                          \
# 4                        ...
# 8                        ...
#
#                    REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 4  Latin America & Caribbean      9.0      9.0         4.0 -99.0      1.0
# 8        East Asia & Pacific      9.0      9.0         4.0 -99.0      1.0
#
#    MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 4       0.0       2.0       7.0
# 8       0.0       1.7       5.7
#
#                                             geometry
# 4  (POLYGON ((-66.95992000000001 -54.896810000000...
# 8  (POLYGON ((145.3979781434949 -40.7925485166059...
#
# ...

# %%
pp.iloc[2:5]
# Out:
#    scalerank       featurecla  LABELRANK            SOVEREIGNT SOV_A3  \
# 2          1  Admin-0 country        6.0               Albania    ALB
# 3          1  Admin-0 country        4.0  United Arab Emirates    ARE
# 4          1  Admin-0 country        2.0             Argentina    ARG
#
#    ADM0_DIF  LEVEL               TYPE                 ADMIN ADM0_A3  \
# 2       0.0    2.0  Sovereign country               Albania     ALB
# 3       0.0    2.0  Sovereign country  United Arab Emirates     ARE
# 4       0.0    2.0  Sovereign country             Argentina     ARG
#
#                          ...                          \
# 2                        ...
# 3                        ...
# 4                        ...
#
#                     REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 2       Europe & Central Asia      7.0      7.0         4.0 -99.0      1.0
# 3  Middle East & North Africa     20.0     20.0         6.0 -99.0      1.0
# ...

# %% [markdown]
# *** Selecting columns by index ***

# %%
pp.iloc[:,0:2]
# Out:
#      scalerank       featurecla
# 0            1  Admin-0 country
# 1            1  Admin-0 country
# 2            1  Admin-0 country
# 3            1  Admin-0 country
# 4            1  Admin-0 country
# 5            1  Admin-0 country
# 6            1  Admin-0 country
# 7            3  Admin-0 country
# 8            1  Admin-0 country
# 9            1  Admin-0 country
# 10           1  Admin-0 country
# 11           1  Admin-0 country
# 12           1  Admin-0 country
# 13           1  Admin-0 country
# 14           1  Admin-0 country
# 15           1  Admin-0 country
# 16           1  Admin-0 country
# 17           1  Admin-0 country
# 18           1  Admin-0 country
# 19           1  Admin-0 country
# 20           1  Admin-0 country
# 21           1  Admin-0 country
# 22           1  Admin-0 country
# 23           1  Admin-0 country
# 24           1  Admin-0 country
# 25           1  Admin-0 country
# 26           1  Admin-0 country
# 27           1  Admin-0 country
# ...

# %% [markdown]
# *** Selecting both columns and rows by index ***

# %%
pp.iloc[2:5, 0:2]
# Out:
#    scalerank       featurecla
# 2          1  Admin-0 country
# 3          1  Admin-0 country
# 4          1  Admin-0 country

# %% [markdown]
# *** Filtering rows based on value ***

# %%
pp[pp['NAME'] == 'Portugal']
# Out:
#      scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 130          1  Admin-0 country        2.0   Portugal    PRT       0.0    2.0
#
#                   TYPE     ADMIN ADM0_A3  \
# 130  Sovereign country  Portugal     PRT
#
#                            ...                                      REGION_WB  \
# 130                        ...                          Europe & Central Asia
#
#     NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  MIN_ZOOM MIN_LABEL  \
# 130      8.0      8.0         5.0 -99.0      1.0       0.0       3.0
#
#     MAX_LABEL                                           geometry
# 130       8.0  POLYGON ((-9.034817674180246 41.88057058365968...
#
# [1 rows x 72 columns]

# %%
pp[pp['NAME'] != 'Poland']
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 1            1  Admin-0 country        3.0                       Angola
# 2            1  Admin-0 country        6.0                      Albania
# 3            1  Admin-0 country        4.0         United Arab Emirates
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 6            1  Admin-0 country        4.0                   Antarctica
# 7            3  Admin-0 country        6.0                       France
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 11           1  Admin-0 country        6.0                      Burundi
# ...

# %%
pp[pp['MIN_ZOOM'] > 0]
# Out:
#      scalerank       featurecla  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 132          1  Admin-0 country        5.0          Israel    IS1       1.0
# 137          1  Admin-0 country        7.0  Western Sahara    SAH       0.0
# 145          1  Admin-0 country        5.0      Somaliland    SOL       0.0
#
#      LEVEL           TYPE           ADMIN ADM0_A3  \
# 132    2.0       Disputed       Palestine     PSX
# 137    2.0  Indeterminate  Western Sahara     SAH
# 145    2.0  Indeterminate      Somaliland     SOL
#
#                            ...                          \
# 132                        ...
# 137                        ...
# 145                        ...
#
#                       REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 132  Middle East & North Africa      9.0      9.0         4.0 -99.0    -99.0
# 137  Middle East & North Africa      9.0     14.0         7.0 -99.0      1.0
# ...

# %%
pp[pp['MIN_ZOOM'] >= 7]
# Out:
#      scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 132          1  Admin-0 country        5.0     Israel    IS1       1.0    2.0
#
#          TYPE      ADMIN ADM0_A3  \
# 132  Disputed  Palestine     PSX
#
#                            ...                          \
# 132                        ...
#
#                       REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 132  Middle East & North Africa      9.0      9.0         4.0 -99.0    -99.0
#
#      MIN_ZOOM MIN_LABEL MAX_LABEL  \
# 132       7.0       4.5       9.5
#
#                                               geometry
# 132  POLYGON ((35.39756066258605 31.48908600516758,...
#
# [1 rows x 72 columns]

# %%
pp[(pp['MIN_ZOOM'] >= 4) & (pp['MIN_ZOOM'] <= 7)]
# Out:
#      scalerank       featurecla  LABELRANK      SOVEREIGNT SOV_A3  ADM0_DIF  \
# 132          1  Admin-0 country        5.0          Israel    IS1       1.0
# 137          1  Admin-0 country        7.0  Western Sahara    SAH       0.0
# 145          1  Admin-0 country        5.0      Somaliland    SOL       0.0
#
#      LEVEL           TYPE           ADMIN ADM0_A3  \
# 132    2.0       Disputed       Palestine     PSX
# 137    2.0  Indeterminate  Western Sahara     SAH
# 145    2.0  Indeterminate      Somaliland     SOL
#
#                            ...                          \
# 132                        ...
# 137                        ...
# 145                        ...
#
#                       REGION_WB NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  \
# 132  Middle East & North Africa      9.0      9.0         4.0 -99.0    -99.0
# 137  Middle East & North Africa      9.0     14.0         7.0 -99.0      1.0
# ...

# %%
pp[(pp['NAME'] == 'Portugal') | (pp['NAME'] == 'Spain')]
# Out:
#      scalerank       featurecla  LABELRANK SOVEREIGNT SOV_A3  ADM0_DIF  LEVEL  \
# 49           1  Admin-0 country        2.0      Spain    ESP       0.0    2.0
# 130          1  Admin-0 country        2.0   Portugal    PRT       0.0    2.0
#
#                   TYPE     ADMIN ADM0_A3  \
# 49   Sovereign country     Spain     ESP
# 130  Sovereign country  Portugal     PRT
#
#                            ...                                      REGION_WB  \
# 49                         ...                          Europe & Central Asia
# 130                        ...                          Europe & Central Asia
#
#     NAME_LEN LONG_LEN  ABBREV_LEN  TINY HOMEPART  MIN_ZOOM MIN_LABEL  \
# 49       5.0      5.0         3.0 -99.0      1.0       0.0       2.0
# 130      8.0      8.0         5.0 -99.0      1.0       0.0       3.0
#
#     MAX_LABEL                                           geometry
# 49        7.0  POLYGON ((-9.034817674180246 41.88057058365968...
# ...

# %%
pp.sort_values('NAME')
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 2            1  Admin-0 country        6.0                      Albania
# 45           1  Admin-0 country        3.0                      Algeria
# 1            1  Admin-0 country        3.0                       Angola
# 6            1  Admin-0 country        4.0                   Antarctica
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 17           1  Admin-0 country        4.0                  The Bahamas
# 15           1  Admin-0 country        3.0                   Bangladesh
# ...

# %%
pp.sort_values('NAME', ascending=False)
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 176          1  Admin-0 country        3.0                     Zimbabwe
# 175          1  Admin-0 country        3.0                       Zambia
# 173          1  Admin-0 country        3.0                        Yemen
# 137          1  Admin-0 country        7.0               Western Sahara
# 171          1  Admin-0 country        2.0                      Vietnam
# 170          1  Admin-0 country        3.0                    Venezuela
# 172          1  Admin-0 country        4.0                      Vanuatu
# 169          1  Admin-0 country        3.0                   Uzbekistan
# 167          1  Admin-0 country        4.0                      Uruguay
# 168          1  Admin-0 country        2.0     United States of America
# 57           1  Admin-0 country        2.0               United Kingdom
# 3            1  Admin-0 country        4.0         United Arab Emirates
# ...

# %%
pp.sort_values(['NAME', 'REGION_WB'])
# Out:
#      scalerank       featurecla  LABELRANK                   SOVEREIGNT  \
# 0            1  Admin-0 country        3.0                  Afghanistan
# 2            1  Admin-0 country        6.0                      Albania
# 45           1  Admin-0 country        3.0                      Algeria
# 1            1  Admin-0 country        3.0                       Angola
# 6            1  Admin-0 country        4.0                   Antarctica
# 4            1  Admin-0 country        2.0                    Argentina
# 5            1  Admin-0 country        6.0                      Armenia
# 8            1  Admin-0 country        2.0                    Australia
# 9            1  Admin-0 country        4.0                      Austria
# 10           1  Admin-0 country        5.0                   Azerbaijan
# 17           1  Admin-0 country        4.0                  The Bahamas
# 15           1  Admin-0 country        3.0                   Bangladesh
# ...
